# %% [markdown]
# # Комплексный обзор и анализ алгоритма для задачи выбора жениха
#
# ### **Общая цель и описание задачи**
# Алгоритм решает задачу оптимальной остановки, известную как задача "Секретаря" (или "задача выбора жениха"), в которой целью является максимизация вероятности выбора наилучшего кандидата (жениха) из последовательности. Алгоритм анализирует ранжированные по качеству предложения кандидатов и принимает решение о том, когда остановиться и выбрать кандидата, основываясь на накопленной информации.
#
# ### **Используемый подход**
# Алгоритм основан на методе обучения с подкреплением (RL) и реализован с помощью модели PPO (Proximal Policy Optimization), одного из популярных подходов в RL. PPO является методом политики, который обучает агента (в данном случае — алгоритм выбора жениха) на основе опыта взаимодействий с окружением (средой), обновляя политику выборов (стратегию принятия решений) таким образом, чтобы улучшить вероятности достижения поставленной цели — выбрать наилучшего кандидата.
#
# #### **Основные особенности PPO:**
# - **Постепенное обновление политики:** PPO ограничивает обновления политики с использованием "клиппинга" (clip range), чтобы предотвратить слишком резкие изменения, что делает обучение более стабильным и менее подверженным перегрузкам.
# - **Использование батчей и мини-батчей:** PPO использует мини-батчи из опыта для обновления политики, что позволяет лучше усреднить градиенты и улучшить общую устойчивость процесса обучения.
# - **Поддержка энтропийного коэффициента (ent_coef):** В алгоритме используется коэффициент энтропии для поддержки исследования (exploration), что помогает агенту рассматривать различные стратегии и избегать преждевременной конвергенции к одной стратегии.
#
# ### **Структура алгоритма**
# 1. **Создание среды (GroomSelectionEnv):**
#    Алгоритм взаимодействует с окружением, которое моделирует процесс выбора жениха. В среде кандидаты представлены как числа, а агент учится оптимально решать, когда остановиться и выбрать лучшего кандидата, основываясь на их ранжировании и индексации.
# 2. **Обучение модели PPO:**
#    - Начальные параметры модели: Для обучения используется нейросеть с политикой `MlpPolicy`, оптимизированной с помощью алгоритма PPO.
#    - Обучение происходит итерациями: За каждый интервал обучения (задан параметром `eval_interval`) модель обучается и оценивается, что позволяет следить за прогрессом в выборе лучших кандидатов.
#    - Сглаживание результатов: Для уменьшения шумов и улучшения стабильности используется скользящее среднее вероятности выбора лучшего кандидата.
# 3. **Оценка и улучшение:**
#    - Оценка вероятности выбора лучшего кандидата выполняется на каждом шаге. Если вероятность улучшилась, то среда вознаграждает модель, устанавливая награду за улучшение. Это обеспечивает мотивацию модели не только выбирать лучших кандидатов, но и постоянно улучшать свою стратегию.
# 4. **Логирование и визуализация:**
#    - Алгоритм сохраняет логи в файл JSON, что позволяет отслеживать ключевые результаты, такие как количество кандидатов, количество итераций и процент успешных выборов лучших кандидатов.
#    - После завершения обучения строится график, показывающий изменение вероятности выбора лучшего кандидата по мере обучения.
#
# ### **Теоретическое обоснование**
# Задача оптимальной остановки, используемая в этом проекте, является классической математической задачей с реальными приложениями, такими как выбор сотрудников на работу или решения инвестиционных вопросов. Теоретически доказано, что для задачи "Секретаря" существует оптимальная стратегия, которая состоит в том, чтобы пропустить первые \(n/e\) кандидатов (где \(e\) — основание натурального логарифма) и затем выбрать первого кандидата, который превосходит всех предыдущих.
#
# В данном случае, алгоритм PPO изучает похожую стратегию путем взаимодействия с окружением и обучения на основе наград за успешный выбор кандидатов. Это позволяет агенту выявить оптимальные моменты для выбора женихов, не полагаясь на предопределенные правила, а обучаясь адаптироваться к разным числам кандидатов и ситуациям.
#
# ### **Заключение**
# Представленный алгоритм представляет собой гибкий и адаптивный подход к решению задачи выбора жениха на основе обучения с подкреплением. Он эффективно использует возможности алгоритма PPO для постоянного улучшения стратегии выбора кандидатов через итерации, оценку и обратную связь. Использование методов RL в задаче выбора жениха является удачным примером применения современных методов машинного обучения для решения классических задач оптимальной остановки.

# %% [markdown]
# # Входные данные модели:
# Текущий рейтинг кандидата: candidate_value (заданный плавающими точками диапазоне от 0.0 до 1.0).
#
# Прогресс: progress, показывающий, на каком этапе просмотра модель находится.
#
# Общее количество кандидатов: self.n_candidates.
#
# Список просмотренных кандидатов: viewed_candidates
#
# # Награды:
# Выбор лучшего кандидата:
#
# Награда: 1.0
#
# Описание: Мотивирует модель выбирать кандидата с наивысшим рейтингом.
#
# Выбор кандидата выше самого высокого из просмотренных:
#
# Награда: 0.1
#
# Описание: Поощряет модель за выбор кандидатов, рейтинг которых выше самого высокого значения всех просмотренных ранее.
#
# Награда за постоянное улучшение:
#
# Награда: Устанавливается функцией set_improvement_reward.
#
# Описание: Мотивирует модель на постоянное улучшение результатов.
#
# # Штрафы:
# Штрафы отсутствуют в текущем коде.

# %% [markdown]
# # Импорт необходимых библиотек

# %%
import json
import numpy as np
import gymnasium as gym
import seaborn as sns
import matplotlib.pyplot as plt


from gymnasium import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv

# %% [markdown]
# # Класс для создания среды выбора кандидатов

# %%
class GroomSelectionEnv(gym.Env):  
    def __init__(self, n_candidates=100):
        super().__init__()
        self.n_candidates = n_candidates  # Количество кандидатов
        self.min_rating = 0.0  # Минимальный рейтинг кандидата
        self.max_rating = 1.0  # Максимальный рейтинг кандидата
        self.candidates = []  # Список кандидатов
        self.current_step = 0  # Текущий шаг
        self.best_candidate_index = -1  # Индекс лучшего кандидата
        self.improvement_reward = 0  # Награда за улучшение
        self.skipped_grooms_count = 0  # Количество пропущенных кандидатов
        self.viewed_candidates = []  # Список просмотренных кандидатов

        self.action_space = spaces.Discrete(2)  # Дискретное пространство действий (2 действия: выбрать или пропустить)
        self.observation_space = spaces.Box(
            low=0, high=1, shape=(self.n_candidates+2,), dtype=np.float32  # Пространство наблюдений (включая кандидатов и прогресс)
        )

    def step(self, action):  # Метод для выполнения шага в среде
        if self.current_step >= self.n_candidates - 1:  # Если достигнут последний шаг
            terminated = True  # Эпизод завершен
            chosen_groom = True  # Кандидат выбран

            if self.current_step - 1 == self.best_candidate_index:  # Если текущий кандидат лучший
                reward = 1.0  # Награда за выбор лучшего кандидата
            else:
                reward = 0.0  # Минимальная награда за пропуск лучшего кандидата
            reward += self.improvement_reward  # Добавление награды за улучшение
            return self._get_obs(), reward, terminated, False, {"chosen_groom": chosen_groom}  # Возвращаем наблюдения, награду, статус завершения и информацию

        reward = 0  # Изначальная награда
        terminated = False  # Эпизод не завершен
        chosen_groom = False  # Кандидат не выбран

        if action == 1:  # Если действие — выбрать кандидата
            chosen_groom = True
            if self.current_step == self.best_candidate_index:  # Если выбран лучший кандидат
                reward = 1.0  # Награда за выбор лучшего кандидата
            else:
                if self.viewed_candidates and self.candidates[self.current_step] > max(self.viewed_candidates):  # Если текущий кандидат лучше всех просмотренных
                    reward = 0.1  # Награда за выбор кандидата выше самого высокого из просмотренных
            reward += self.improvement_reward  # Добавление награды за улучшение
            terminated = True  # Эпизод завершен
        else:  # Если действие — пропустить кандидата
            self.viewed_candidates.append(self.candidates[self.current_step])  # Запоминаем текущего кандидата
            self.skipped_grooms_count += 1  # Увеличиваем количество пропущенных кандидатов
            self.current_step += 1  # Переходим к следующему шагу

        return self._get_obs(), reward, terminated, False, {"chosen_groom": chosen_groom}  # Возвращаем наблюдения, награду, статус завершения и информацию

    def reset(self, seed=None, options=None):  # Метод для сброса среды
        super().reset(seed=seed)
        self.candidates = np.random.uniform(self.min_rating, self.max_rating, self.n_candidates)  # Генерация списка кандидатов
        np.random.shuffle(self.candidates)  # Перемешиваем кандидатов случайным образом
        self.best_candidate_index = np.argmax(self.candidates)  # Индекс лучшего кандидата
        self.current_step = 0  # Сброс текущего шага
        self.skipped_grooms_count = 0  # Сброс количества пропущенных кандидатов
        self.viewed_candidates = []  # Сброс списка просмотренных кандидатов
        return self._get_obs(), {}  # Возвращаем начальные наблюдения и информацию

    def _get_obs(self):  # Метод для получения текущих наблюдений
        if self.current_step >= self.n_candidates:
            candidate_value = self.candidates[-1]  # Если достигнут последний кандидат
        else:
            candidate_value = self.candidates[self.current_step]  # Текущий кандидат

        progress = min(1.0, self.current_step / self.n_candidates)  # Прогресс по кандидатам
        viewed_candidates = np.pad(np.array(self.viewed_candidates, dtype=np.float32), (0, self.n_candidates - len(self.viewed_candidates)), 'constant')  # Преобразуем список просмотренных кандидатов в фиксированный размер
        return np.concatenate(([candidate_value], [progress], viewed_candidates), axis=0)  # Возвращаем массив наблюдений

    def set_improvement_reward(self, reward):  # Метод для установки награды за улучшение
        self.improvement_reward = reward

# %% [markdown]
# # Вспомогательная функция для преобразования данных в сериализуемые типы

# %%
def convert_to_serializable(data):
    if isinstance(data, (np.float32, np.float64)):
        return float(data)  # Преобразуем float32 и float64 в обычный float
    elif isinstance(data, (np.int32, np.int64)):
        return int(data)  # Преобразуем int32 и int64 в обычный int
    elif isinstance(data, np.bool_):
        return bool(data)  # Преобразуем np.bool_ в обычный bool
    elif isinstance(data, list):
        return [convert_to_serializable(item) for item in data]  # Рекурсивно обрабатываем список
    elif isinstance(data, dict):
        return {key: convert_to_serializable(value) for key, value in data.items()}  # Рекурсивно обрабатываем словарь
    return data  # Возвращаем неизмененные данные

# %% [markdown]
# # Функция для оценки вероятности выбора лучшего жениха

# %%
def evaluate_best_groom_probability(env, model, n_episodes=100, log=False):
    total_best_groom_selections = 0  # Счетчик правильных выборов лучшего жениха
    results = []  # Логи для финальной оценки, если log=True
    
    for episode in range(n_episodes):
        obs, _ = env.reset()  # Сбрасываем среду
        done = False  # Флаг завершения эпизода
        skipped_grooms_count = 0  # Счетчик пропущенных женихов
        episode_log = {"iteration": episode + 1, "steps": []}  # Лог для текущей итерации
        
        while not done:
            action, _states = model.predict(obs, deterministic=True)  # Прогнозируем действие модели
            obs, reward, terminated, truncated, info = env.step(action)  # Выполняем шаг
            done = terminated or truncated  # Проверяем, завершен ли эпизод
            
            # Логируем только если флаг log=True
            if log:
                step_log = {
                    "current_step": env.current_step + 1,  # Текущий шаг (прибавляем 1 для более понятного отображения)
                    "current_groom_value": round(float(obs[0]), 3),  # Текущее значение жениха
                    "comparison_groom_value": round(np.max(env.candidates[:env.current_step + 1]), 3),  # Максимальное значение среди пропущенных женихов
                    "action": "skip" if action == 0 else "select",  # Действие: пропуск или выбор
                    "best_groom_value": round(env.candidates[env.best_candidate_index], 3),  # Значение лучшего жениха
                    "best_groom_index": env.best_candidate_index  # Индекс лучшего жениха
                }
                episode_log["steps"].append(step_log)  # Добавляем лог шага в лог эпизода
                
            if action == 0:  # Если действие – пропуск жениха
                skipped_grooms_count += 1  # Увеличиваем счетчик пропусков
        
        selected_best_groom = bool(env.current_step == env.best_candidate_index)  # Проверяем, был ли выбран лучший жених
        episode_log["selected_best_groom"] = selected_best_groom  # Логируем результат выбора
        episode_log["skipped_grooms_count"] = skipped_grooms_count  # Логируем количество пропущенных женихов
        
        if selected_best_groom:
            total_best_groom_selections += 1  # Увеличиваем счетчик правильных выборов
        
        if log:
            results.append(episode_log)  # Сохраняем лог эпизода
    
    probability = total_best_groom_selections / n_episodes  # Вычисляем вероятность выбора лучшего жениха
    
    if log:
    # Если параметр log установлен в True, создается лог данных для записи в файл
        log_data = {
            "n_candidates": env.n_candidates,  # Количество кандидатов
            "n_iterations": n_episodes,        # Количество итераций
            "best_selection_percentage": float(probability * 100),  # Вероятность выбора лучшего кандидата в процентах
            "details": results  # Детальная информация о результатах
        }
        log_filename = "groom_selection_log.json"  # Имя файла для сохранения лога
        with open(log_filename, "w") as f:
            # Открываем файл на запись и сохраняем данные в формате JSON
            json.dump(convert_to_serializable(log_data), f, indent=4)
        print(f"Лог сохранен в файл: {log_filename}")  # Сообщение о том, что лог сохранен
        
    return probability  # Возвращаем вероятность выбора лучшего жениха

# %% [markdown]
# # Функция для обучения модели

# %%
def train_model(env, model, total_timesteps=500000, eval_interval=1000, eval_episodes=100):
    train_model.last_probability = 0  # Инициализируем переменную для последней вероятности
    train_model.best_probability = 0  # Инициализируем переменную для лучшей вероятности
    probabilities = []  # Список для хранения вероятностей на каждом шаге
    
    # Скользящее среднее для сглаживания вероятности
    window_size = 3  # Размер окна для скользящего среднего
    last_probabilities = [0] * window_size  # Инициализируем массив для хранения последних вероятностей
    print("Обучение алгоритма:")  # Сообщение о начале обучения
    
    for step in range(0, total_timesteps, eval_interval):
        # Основной цикл обучения, выполняем обучение с интервалом оценки
        model.learn(total_timesteps=eval_interval, reset_num_timesteps=False, progress_bar=False)
        
        # Оцениваем вероятность выбора лучшего жениха без логирования во время обучения
        probability = evaluate_best_groom_probability(env, model, n_episodes=eval_episodes, log=False)
        
        # Обновляем скользящее среднее
        last_probabilities = last_probabilities[1:] + [probability]  # Добавляем текущую вероятность
        smoothed_probability = sum(last_probabilities) / window_size  # Вычисляем скользящее среднее
        
        # Проверяем, улучшилась ли вероятность
        if smoothed_probability > train_model.best_probability:
            # Если вероятность улучшилась, рассчитываем награду за улучшение
            improvement = smoothed_probability - train_model.best_probability  # Рассчитываем улучшение
            improvement_reward = min(0.1, improvement)  # Ограничиваем максимальное улучшение
            train_model.best_probability = smoothed_probability  # Обновляем лучшую вероятность
            env.set_improvement_reward(improvement_reward)  # Устанавливаем награду за улучшение в окружении
        else:
            # Если улучшения нет, устанавливаем минимальную награду
            if train_model.best_probability - smoothed_probability < 0.1:
                env.set_improvement_reward(0.01)  # Минимальная награда при небольшом снижении
            else:
                env.set_improvement_reward(0)  # Награда равна нулю при значительном ухудшении
        
        # Выводим информацию о шаге обучения и текущей вероятности
        print(f"Шаг {step}: Вероятность выбора лучшего жениха: {probability:.2f}")
        
        train_model.last_probability = probability  # Обновляем последнюю вероятность
        probabilities.append(probability)  # Добавляем вероятность в список
    
    return probabilities  # Возвращаем список вероятностей

# %% [markdown]
# # Создание модели

# %%
env = GroomSelectionEnv(n_candidates=100)  # Создаем окружение с 100 кандидатами
vec_env = DummyVecEnv([lambda: env])  # Оборачиваем окружение для работы с векторизированной средой
model = PPO(
    "MlpPolicy",  # Используем многослойную политику
    vec_env,  # Передаем окружение
    learning_rate=0.0001,  # Снижаем скорость обучения для более стабильного обучения
    n_steps=2048,  # Увеличиваем количество шагов в одном батче
    batch_size=64,  # Размер батча
    ent_coef=0.003,  # Коэффициент энтропии для уменьшения случайности в обучении
    gamma=0.99,  # Коэффициент дисконтирования для будущих наград
    verbose=0,  # Выключаем вывод подробной информации
    clip_range=0.1,  # Ограничиваем clip_range для консервативных обновлений
)

# %% [markdown]
# # Обучение модели

# %%
probabilities = train_model(env, model, total_timesteps=500000)
# Out:
# Обучение алгоритма:
# Шаг 0: Вероятность выбора лучшего жениха: 0.00
# Шаг 1000: Вероятность выбора лучшего жениха: 0.02
# Шаг 2000: Вероятность выбора лучшего жениха: 0.02
# Шаг 3000: Вероятность выбора лучшего жениха: 0.05
# Шаг 4000: Вероятность выбора лучшего жениха: 0.01
# Шаг 5000: Вероятность выбора лучшего жениха: 0.06
# Шаг 6000: Вероятность выбора лучшего жениха: 0.03
# Шаг 7000: Вероятность выбора лучшего жениха: 0.02
# Шаг 8000: Вероятность выбора лучшего жениха: 0.02
# Шаг 9000: Вероятность выбора лучшего жениха: 0.04
# Шаг 10000: Вероятность выбора лучшего жениха: 0.01
# Шаг 11000: Вероятность выбора лучшего жениха: 0.04
# Шаг 12000: Вероятность выбора лучшего жениха: 0.03
# Шаг 13000: Вероятность выбора лучшего жениха: 0.04
# Шаг 14000: Вероятность выбора лучшего жениха: 0.03
# Шаг 15000: Вероятность выбора лучшего жениха: 0.01
# Шаг 16000: Вероятность выбора лучшего жениха: 0.03
# Шаг 17000: Вероятность выбора лучшего жениха: 0.02
# Шаг 18000: Вероятность выбора лучшего жениха: 0.03
# Шаг 19000: Вероятность выбора лучшего жениха: 0.01
# Шаг 20000: Вероятность выбора лучшего жениха: 0.02
# Шаг 21000: Вероятность выбора лучшего жениха: 0.07
# Шаг 22000: Вероятность выбора лучшего жениха: 0.03
# Шаг 23000: Вероятность выбора лучшего жениха: 0.03
# Шаг 24000: Вероятность выбора лучшего жениха: 0.03
# Шаг 25000: Вероятность выбора лучшего жениха: 0.04
# Шаг 26000: Вероятность выбора лучшего жениха: 0.08
# Шаг 27000: Вероятность выбора лучшего жениха: 0.02
# Шаг 28000: Вероятность выбора лучшего жениха: 0.04
# Шаг 29000: Вероятность выбора лучшего жениха: 0.04
# Шаг 30000: Вероятность выбора лучшего жениха: 0.02
# Шаг 31000: Вероятность выбора лучшего жениха: 0.03
# Шаг 32000: Вероятность выбора лучшего жениха: 0.08
# Шаг 33000: Вероятность выбора лучшего жениха: 0.05
# Шаг 34000: Вероятность выбора лучшего жениха: 0.05
# Шаг 35000: Вероятность выбора лучшего жениха: 0.06
# Шаг 36000: Вероятность выбора лучшего жениха: 0.03
# Шаг 37000: Вероятность выбора лучшего жениха: 0.07
# Шаг 38000: Вероятность выбора лучшего жениха: 0.03
# Шаг 39000: Вероятность выбора лучшего жениха: 0.03
# Шаг 40000: Вероятность выбора лучшего жениха: 0.10
# Шаг 41000: Вероятность выбора лучшего жениха: 0.06
# Шаг 42000: Вероятность выбора лучшего жениха: 0.07
# Шаг 43000: Вероятность выбора лучшего жениха: 0.08
# Шаг 44000: Вероятность выбора лучшего жениха: 0.11
# Шаг 45000: Вероятность выбора лучшего жениха: 0.10
# Шаг 46000: Вероятность выбора лучшего жениха: 0.06
# Шаг 47000: Вероятность выбора лучшего жениха: 0.08
# Шаг 48000: Вероятность выбора лучшего жениха: 0.07
# Шаг 49000: Вероятность выбора лучшего жениха: 0.14
# Шаг 50000: Вероятность выбора лучшего жениха: 0.09
# Шаг 51000: Вероятность выбора лучшего жениха: 0.07
# Шаг 52000: Вероятность выбора лучшего жениха: 0.06
# Шаг 53000: Вероятность выбора лучшего жениха: 0.04
# Шаг 54000: Вероятность выбора лучшего жениха: 0.07
# Шаг 55000: Вероятность выбора лучшего жениха: 0.11
# Шаг 56000: Вероятность выбора лучшего жениха: 0.10
# Шаг 57000: Вероятность выбора лучшего жениха: 0.05
# Шаг 58000: Вероятность выбора лучшего жениха: 0.09
# Шаг 59000: Вероятность выбора лучшего жениха: 0.12
# Шаг 60000: Вероятность выбора лучшего жениха: 0.13
# Шаг 61000: Вероятность выбора лучшего жениха: 0.10
# Шаг 62000: Вероятность выбора лучшего жениха: 0.09
# Шаг 63000: Вероятность выбора лучшего жениха: 0.10
# Шаг 64000: Вероятность выбора лучшего жениха: 0.09
# Шаг 65000: Вероятность выбора лучшего жениха: 0.10
# Шаг 66000: Вероятность выбора лучшего жениха: 0.15
# Шаг 67000: Вероятность выбора лучшего жениха: 0.13
# Шаг 68000: Вероятность выбора лучшего жениха: 0.14
# Шаг 69000: Вероятность выбора лучшего жениха: 0.15
# Шаг 70000: Вероятность выбора лучшего жениха: 0.21
# Шаг 71000: Вероятность выбора лучшего жениха: 0.14
# Шаг 72000: Вероятность выбора лучшего жениха: 0.23
# Шаг 73000: Вероятность выбора лучшего жениха: 0.15
# Шаг 74000: Вероятность выбора лучшего жениха: 0.15
# Шаг 75000: Вероятность выбора лучшего жениха: 0.20
# Шаг 76000: Вероятность выбора лучшего жениха: 0.16
# Шаг 77000: Вероятность выбора лучшего жениха: 0.19
# Шаг 78000: Вероятность выбора лучшего жениха: 0.23
# Шаг 79000: Вероятность выбора лучшего жениха: 0.15
# Шаг 80000: Вероятность выбора лучшего жениха: 0.20
# Шаг 81000: Вероятность выбора лучшего жениха: 0.14
# Шаг 82000: Вероятность выбора лучшего жениха: 0.15
# Шаг 83000: Вероятность выбора лучшего жениха: 0.20
# Шаг 84000: Вероятность выбора лучшего жениха: 0.17
# Шаг 85000: Вероятность выбора лучшего жениха: 0.23
# Шаг 86000: Вероятность выбора лучшего жениха: 0.15
# Шаг 87000: Вероятность выбора лучшего жениха: 0.25
# Шаг 88000: Вероятность выбора лучшего жениха: 0.20
# Шаг 89000: Вероятность выбора лучшего жениха: 0.13
# Шаг 90000: Вероятность выбора лучшего жениха: 0.14
# Шаг 91000: Вероятность выбора лучшего жениха: 0.09
# Шаг 92000: Вероятность выбора лучшего жениха: 0.17
# Шаг 93000: Вероятность выбора лучшего жениха: 0.12
# Шаг 94000: Вероятность выбора лучшего жениха: 0.14
# Шаг 95000: Вероятность выбора лучшего жениха: 0.17
# Шаг 96000: Вероятность выбора лучшего жениха: 0.17
# Шаг 97000: Вероятность выбора лучшего жениха: 0.23
# Шаг 98000: Вероятность выбора лучшего жениха: 0.20
# Шаг 99000: Вероятность выбора лучшего жениха: 0.24
# Шаг 100000: Вероятность выбора лучшего жениха: 0.15
# Шаг 101000: Вероятность выбора лучшего жениха: 0.19
# Шаг 102000: Вероятность выбора лучшего жениха: 0.17
# Шаг 103000: Вероятность выбора лучшего жениха: 0.16
# Шаг 104000: Вероятность выбора лучшего жениха: 0.21
# Шаг 105000: Вероятность выбора лучшего жениха: 0.15
# Шаг 106000: Вероятность выбора лучшего жениха: 0.25
# Шаг 107000: Вероятность выбора лучшего жениха: 0.20
# Шаг 108000: Вероятность выбора лучшего жениха: 0.17
# Шаг 109000: Вероятность выбора лучшего жениха: 0.21
# Шаг 110000: Вероятность выбора лучшего жениха: 0.22
# Шаг 111000: Вероятность выбора лучшего жениха: 0.26
# Шаг 112000: Вероятность выбора лучшего жениха: 0.28
# Шаг 113000: Вероятность выбора лучшего жениха: 0.18
# Шаг 114000: Вероятность выбора лучшего жениха: 0.23
# Шаг 115000: Вероятность выбора лучшего жениха: 0.20
# Шаг 116000: Вероятность выбора лучшего жениха: 0.26
# Шаг 117000: Вероятность выбора лучшего жениха: 0.20
# Шаг 118000: Вероятность выбора лучшего жениха: 0.25
# Шаг 119000: Вероятность выбора лучшего жениха: 0.20
# Шаг 120000: Вероятность выбора лучшего жениха: 0.23
# Шаг 121000: Вероятность выбора лучшего жениха: 0.22
# Шаг 122000: Вероятность выбора лучшего жениха: 0.18
# Шаг 123000: Вероятность выбора лучшего жениха: 0.13
# Шаг 124000: Вероятность выбора лучшего жениха: 0.26
# Шаг 125000: Вероятность выбора лучшего жениха: 0.24
# Шаг 126000: Вероятность выбора лучшего жениха: 0.25
# Шаг 127000: Вероятность выбора лучшего жениха: 0.22
# Шаг 128000: Вероятность выбора лучшего жениха: 0.15
# Шаг 129000: Вероятность выбора лучшего жениха: 0.24
# Шаг 130000: Вероятность выбора лучшего жениха: 0.21
# Шаг 131000: Вероятность выбора лучшего жениха: 0.25
# Шаг 132000: Вероятность выбора лучшего жениха: 0.20
# Шаг 133000: Вероятность выбора лучшего жениха: 0.16
# Шаг 134000: Вероятность выбора лучшего жениха: 0.23
# Шаг 135000: Вероятность выбора лучшего жениха: 0.22
# Шаг 136000: Вероятность выбора лучшего жениха: 0.26
# Шаг 137000: Вероятность выбора лучшего жениха: 0.25
# Шаг 138000: Вероятность выбора лучшего жениха: 0.17
# Шаг 139000: Вероятность выбора лучшего жениха: 0.23
# Шаг 140000: Вероятность выбора лучшего жениха: 0.20
# Шаг 141000: Вероятность выбора лучшего жениха: 0.22
# Шаг 142000: Вероятность выбора лучшего жениха: 0.13
# Шаг 143000: Вероятность выбора лучшего жениха: 0.14
# Шаг 144000: Вероятность выбора лучшего жениха: 0.13
# Шаг 145000: Вероятность выбора лучшего жениха: 0.21
# Шаг 146000: Вероятность выбора лучшего жениха: 0.16
# Шаг 147000: Вероятность выбора лучшего жениха: 0.16
# Шаг 148000: Вероятность выбора лучшего жениха: 0.26
# Шаг 149000: Вероятность выбора лучшего жениха: 0.21
# Шаг 150000: Вероятность выбора лучшего жениха: 0.18
# Шаг 151000: Вероятность выбора лучшего жениха: 0.17
# Шаг 152000: Вероятность выбора лучшего жениха: 0.18
# Шаг 153000: Вероятность выбора лучшего жениха: 0.17
# Шаг 154000: Вероятность выбора лучшего жениха: 0.25
# Шаг 155000: Вероятность выбора лучшего жениха: 0.25
# Шаг 156000: Вероятность выбора лучшего жениха: 0.24
# Шаг 157000: Вероятность выбора лучшего жениха: 0.14
# Шаг 158000: Вероятность выбора лучшего жениха: 0.21
# Шаг 159000: Вероятность выбора лучшего жениха: 0.25
# Шаг 160000: Вероятность выбора лучшего жениха: 0.24
# Шаг 161000: Вероятность выбора лучшего жениха: 0.19
# Шаг 162000: Вероятность выбора лучшего жениха: 0.21
# Шаг 163000: Вероятность выбора лучшего жениха: 0.21
# Шаг 164000: Вероятность выбора лучшего жениха: 0.27
# Шаг 165000: Вероятность выбора лучшего жениха: 0.20
# Шаг 166000: Вероятность выбора лучшего жениха: 0.18
# Шаг 167000: Вероятность выбора лучшего жениха: 0.25
# Шаг 168000: Вероятность выбора лучшего жениха: 0.20
# Шаг 169000: Вероятность выбора лучшего жениха: 0.23
# Шаг 170000: Вероятность выбора лучшего жениха: 0.18
# Шаг 171000: Вероятность выбора лучшего жениха: 0.16
# Шаг 172000: Вероятность выбора лучшего жениха: 0.23
# Шаг 173000: Вероятность выбора лучшего жениха: 0.29
# Шаг 174000: Вероятность выбора лучшего жениха: 0.18
# Шаг 175000: Вероятность выбора лучшего жениха: 0.24
# Шаг 176000: Вероятность выбора лучшего жениха: 0.30
# Шаг 177000: Вероятность выбора лучшего жениха: 0.23
# Шаг 178000: Вероятность выбора лучшего жениха: 0.21
# Шаг 179000: Вероятность выбора лучшего жениха: 0.17
# Шаг 180000: Вероятность выбора лучшего жениха: 0.23
# Шаг 181000: Вероятность выбора лучшего жениха: 0.27
# Шаг 182000: Вероятность выбора лучшего жениха: 0.17
# Шаг 183000: Вероятность выбора лучшего жениха: 0.23
# Шаг 184000: Вероятность выбора лучшего жениха: 0.25
# Шаг 185000: Вероятность выбора лучшего жениха: 0.26
# Шаг 186000: Вероятность выбора лучшего жениха: 0.27
# Шаг 187000: Вероятность выбора лучшего жениха: 0.29
# Шаг 188000: Вероятность выбора лучшего жениха: 0.29
# Шаг 189000: Вероятность выбора лучшего жениха: 0.23
# Шаг 190000: Вероятность выбора лучшего жениха: 0.26
# Шаг 191000: Вероятность выбора лучшего жениха: 0.22
# Шаг 192000: Вероятность выбора лучшего жениха: 0.32
# Шаг 193000: Вероятность выбора лучшего жениха: 0.20
# Шаг 194000: Вероятность выбора лучшего жениха: 0.19
# Шаг 195000: Вероятность выбора лучшего жениха: 0.19
# Шаг 196000: Вероятность выбора лучшего жениха: 0.22
# Шаг 197000: Вероятность выбора лучшего жениха: 0.29
# Шаг 198000: Вероятность выбора лучшего жениха: 0.24
# Шаг 199000: Вероятность выбора лучшего жениха: 0.26
# Шаг 200000: Вероятность выбора лучшего жениха: 0.29
# Шаг 201000: Вероятность выбора лучшего жениха: 0.31
# Шаг 202000: Вероятность выбора лучшего жениха: 0.25
# Шаг 203000: Вероятность выбора лучшего жениха: 0.23
# Шаг 204000: Вероятность выбора лучшего жениха: 0.19
# Шаг 205000: Вероятность выбора лучшего жениха: 0.21
# Шаг 206000: Вероятность выбора лучшего жениха: 0.22
# Шаг 207000: Вероятность выбора лучшего жениха: 0.20
# Шаг 208000: Вероятность выбора лучшего жениха: 0.32
# Шаг 209000: Вероятность выбора лучшего жениха: 0.19
# Шаг 210000: Вероятность выбора лучшего жениха: 0.29
# Шаг 211000: Вероятность выбора лучшего жениха: 0.15
# Шаг 212000: Вероятность выбора лучшего жениха: 0.25
# Шаг 213000: Вероятность выбора лучшего жениха: 0.16
# Шаг 214000: Вероятность выбора лучшего жениха: 0.28
# Шаг 215000: Вероятность выбора лучшего жениха: 0.29
# Шаг 216000: Вероятность выбора лучшего жениха: 0.26
# Шаг 217000: Вероятность выбора лучшего жениха: 0.22
# Шаг 218000: Вероятность выбора лучшего жениха: 0.26
# Шаг 219000: Вероятность выбора лучшего жениха: 0.26
# Шаг 220000: Вероятность выбора лучшего жениха: 0.28
# Шаг 221000: Вероятность выбора лучшего жениха: 0.16
# Шаг 222000: Вероятность выбора лучшего жениха: 0.24
# Шаг 223000: Вероятность выбора лучшего жениха: 0.27
# Шаг 224000: Вероятность выбора лучшего жениха: 0.26
# Шаг 225000: Вероятность выбора лучшего жениха: 0.29
# Шаг 226000: Вероятность выбора лучшего жениха: 0.25
# Шаг 227000: Вероятность выбора лучшего жениха: 0.16
# Шаг 228000: Вероятность выбора лучшего жениха: 0.26
# Шаг 229000: Вероятность выбора лучшего жениха: 0.30
# Шаг 230000: Вероятность выбора лучшего жениха: 0.22
# Шаг 231000: Вероятность выбора лучшего жениха: 0.26
# Шаг 232000: Вероятность выбора лучшего жениха: 0.16
# Шаг 233000: Вероятность выбора лучшего жениха: 0.19
# Шаг 234000: Вероятность выбора лучшего жениха: 0.24
# Шаг 235000: Вероятность выбора лучшего жениха: 0.24
# Шаг 236000: Вероятность выбора лучшего жениха: 0.25
# Шаг 237000: Вероятность выбора лучшего жениха: 0.33
# Шаг 238000: Вероятность выбора лучшего жениха: 0.23
# Шаг 239000: Вероятность выбора лучшего жениха: 0.17
# Шаг 240000: Вероятность выбора лучшего жениха: 0.22
# Шаг 241000: Вероятность выбора лучшего жениха: 0.23
# Шаг 242000: Вероятность выбора лучшего жениха: 0.17
# Шаг 243000: Вероятность выбора лучшего жениха: 0.20
# Шаг 244000: Вероятность выбора лучшего жениха: 0.22
# Шаг 245000: Вероятность выбора лучшего жениха: 0.21
# Шаг 246000: Вероятность выбора лучшего жениха: 0.30
# Шаг 247000: Вероятность выбора лучшего жениха: 0.25
# Шаг 248000: Вероятность выбора лучшего жениха: 0.22
# Шаг 249000: Вероятность выбора лучшего жениха: 0.28
# Шаг 250000: Вероятность выбора лучшего жениха: 0.23
# Шаг 251000: Вероятность выбора лучшего жениха: 0.22
# Шаг 252000: Вероятность выбора лучшего жениха: 0.28
# Шаг 253000: Вероятность выбора лучшего жениха: 0.24
# Шаг 254000: Вероятность выбора лучшего жениха: 0.23
# Шаг 255000: Вероятность выбора лучшего жениха: 0.21
# Шаг 256000: Вероятность выбора лучшего жениха: 0.28
# Шаг 257000: Вероятность выбора лучшего жениха: 0.17
# Шаг 258000: Вероятность выбора лучшего жениха: 0.18
# Шаг 259000: Вероятность выбора лучшего жениха: 0.18
# Шаг 260000: Вероятность выбора лучшего жениха: 0.21
# Шаг 261000: Вероятность выбора лучшего жениха: 0.22
# Шаг 262000: Вероятность выбора лучшего жениха: 0.22
# Шаг 263000: Вероятность выбора лучшего жениха: 0.30
# Шаг 264000: Вероятность выбора лучшего жениха: 0.26
# Шаг 265000: Вероятность выбора лучшего жениха: 0.32
# Шаг 266000: Вероятность выбора лучшего жениха: 0.25
# Шаг 267000: Вероятность выбора лучшего жениха: 0.31
# Шаг 268000: Вероятность выбора лучшего жениха: 0.30
# Шаг 269000: Вероятность выбора лучшего жениха: 0.21
# Шаг 270000: Вероятность выбора лучшего жениха: 0.26
# Шаг 271000: Вероятность выбора лучшего жениха: 0.22
# Шаг 272000: Вероятность выбора лучшего жениха: 0.17
# Шаг 273000: Вероятность выбора лучшего жениха: 0.23
# Шаг 274000: Вероятность выбора лучшего жениха: 0.33
# Шаг 275000: Вероятность выбора лучшего жениха: 0.27
# Шаг 276000: Вероятность выбора лучшего жениха: 0.27
# Шаг 277000: Вероятность выбора лучшего жениха: 0.22
# Шаг 278000: Вероятность выбора лучшего жениха: 0.33
# Шаг 279000: Вероятность выбора лучшего жениха: 0.29
# Шаг 280000: Вероятность выбора лучшего жениха: 0.22
# Шаг 281000: Вероятность выбора лучшего жениха: 0.23
# Шаг 282000: Вероятность выбора лучшего жениха: 0.27
# Шаг 283000: Вероятность выбора лучшего жениха: 0.26
# Шаг 284000: Вероятность выбора лучшего жениха: 0.17
# Шаг 285000: Вероятность выбора лучшего жениха: 0.31
# Шаг 286000: Вероятность выбора лучшего жениха: 0.22
# Шаг 287000: Вероятность выбора лучшего жениха: 0.19
# Шаг 288000: Вероятность выбора лучшего жениха: 0.35
# Шаг 289000: Вероятность выбора лучшего жениха: 0.26
# Шаг 290000: Вероятность выбора лучшего жениха: 0.27
# Шаг 291000: Вероятность выбора лучшего жениха: 0.26
# Шаг 292000: Вероятность выбора лучшего жениха: 0.19
# Шаг 293000: Вероятность выбора лучшего жениха: 0.24
# Шаг 294000: Вероятность выбора лучшего жениха: 0.25
# Шаг 295000: Вероятность выбора лучшего жениха: 0.20
# Шаг 296000: Вероятность выбора лучшего жениха: 0.25
# Шаг 297000: Вероятность выбора лучшего жениха: 0.25
# Шаг 298000: Вероятность выбора лучшего жениха: 0.23
# Шаг 299000: Вероятность выбора лучшего жениха: 0.15
# Шаг 300000: Вероятность выбора лучшего жениха: 0.19
# Шаг 301000: Вероятность выбора лучшего жениха: 0.17
# Шаг 302000: Вероятность выбора лучшего жениха: 0.25
# Шаг 303000: Вероятность выбора лучшего жениха: 0.26
# Шаг 304000: Вероятность выбора лучшего жениха: 0.26
# Шаг 305000: Вероятность выбора лучшего жениха: 0.28
# Шаг 306000: Вероятность выбора лучшего жениха: 0.38
# Шаг 307000: Вероятность выбора лучшего жениха: 0.30
# Шаг 308000: Вероятность выбора лучшего жениха: 0.29
# Шаг 309000: Вероятность выбора лучшего жениха: 0.17
# Шаг 310000: Вероятность выбора лучшего жениха: 0.21
# Шаг 311000: Вероятность выбора лучшего жениха: 0.25
# Шаг 312000: Вероятность выбора лучшего жениха: 0.31
# Шаг 313000: Вероятность выбора лучшего жениха: 0.33
# Шаг 314000: Вероятность выбора лучшего жениха: 0.19
# Шаг 315000: Вероятность выбора лучшего жениха: 0.32
# Шаг 316000: Вероятность выбора лучшего жениха: 0.23
# Шаг 317000: Вероятность выбора лучшего жениха: 0.28
# Шаг 318000: Вероятность выбора лучшего жениха: 0.22
# Шаг 319000: Вероятность выбора лучшего жениха: 0.30
# Шаг 320000: Вероятность выбора лучшего жениха: 0.27
# Шаг 321000: Вероятность выбора лучшего жениха: 0.19
# Шаг 322000: Вероятность выбора лучшего жениха: 0.19
# Шаг 323000: Вероятность выбора лучшего жениха: 0.28
# Шаг 324000: Вероятность выбора лучшего жениха: 0.26
# Шаг 325000: Вероятность выбора лучшего жениха: 0.18
# Шаг 326000: Вероятность выбора лучшего жениха: 0.21
# Шаг 327000: Вероятность выбора лучшего жениха: 0.26
# Шаг 328000: Вероятность выбора лучшего жениха: 0.22
# Шаг 329000: Вероятность выбора лучшего жениха: 0.27
# Шаг 330000: Вероятность выбора лучшего жениха: 0.22
# Шаг 331000: Вероятность выбора лучшего жениха: 0.25
# Шаг 332000: Вероятность выбора лучшего жениха: 0.27
# Шаг 333000: Вероятность выбора лучшего жениха: 0.20
# Шаг 334000: Вероятность выбора лучшего жениха: 0.31
# Шаг 335000: Вероятность выбора лучшего жениха: 0.23
# Шаг 336000: Вероятность выбора лучшего жениха: 0.25
# Шаг 337000: Вероятность выбора лучшего жениха: 0.23
# Шаг 338000: Вероятность выбора лучшего жениха: 0.28
# Шаг 339000: Вероятность выбора лучшего жениха: 0.22
# Шаг 340000: Вероятность выбора лучшего жениха: 0.23
# Шаг 341000: Вероятность выбора лучшего жениха: 0.25
# Шаг 342000: Вероятность выбора лучшего жениха: 0.25
# Шаг 343000: Вероятность выбора лучшего жениха: 0.27
# Шаг 344000: Вероятность выбора лучшего жениха: 0.24
# Шаг 345000: Вероятность выбора лучшего жениха: 0.17
# Шаг 346000: Вероятность выбора лучшего жениха: 0.25
# Шаг 347000: Вероятность выбора лучшего жениха: 0.25
# Шаг 348000: Вероятность выбора лучшего жениха: 0.22
# Шаг 349000: Вероятность выбора лучшего жениха: 0.28
# Шаг 350000: Вероятность выбора лучшего жениха: 0.23
# Шаг 351000: Вероятность выбора лучшего жениха: 0.23
# Шаг 352000: Вероятность выбора лучшего жениха: 0.23
# Шаг 353000: Вероятность выбора лучшего жениха: 0.22
# Шаг 354000: Вероятность выбора лучшего жениха: 0.21
# Шаг 355000: Вероятность выбора лучшего жениха: 0.26
# Шаг 356000: Вероятность выбора лучшего жениха: 0.17
# Шаг 357000: Вероятность выбора лучшего жениха: 0.27
# Шаг 358000: Вероятность выбора лучшего жениха: 0.27
# Шаг 359000: Вероятность выбора лучшего жениха: 0.28
# Шаг 360000: Вероятность выбора лучшего жениха: 0.34
# Шаг 361000: Вероятность выбора лучшего жениха: 0.17
# Шаг 362000: Вероятность выбора лучшего жениха: 0.27
# Шаг 363000: Вероятность выбора лучшего жениха: 0.25
# Шаг 364000: Вероятность выбора лучшего жениха: 0.21
# Шаг 365000: Вероятность выбора лучшего жениха: 0.27
# Шаг 366000: Вероятность выбора лучшего жениха: 0.32
# Шаг 367000: Вероятность выбора лучшего жениха: 0.24
# Шаг 368000: Вероятность выбора лучшего жениха: 0.29
# Шаг 369000: Вероятность выбора лучшего жениха: 0.31
# Шаг 370000: Вероятность выбора лучшего жениха: 0.22
# Шаг 371000: Вероятность выбора лучшего жениха: 0.32
# Шаг 372000: Вероятность выбора лучшего жениха: 0.23
# Шаг 373000: Вероятность выбора лучшего жениха: 0.20
# Шаг 374000: Вероятность выбора лучшего жениха: 0.28
# Шаг 375000: Вероятность выбора лучшего жениха: 0.26
# Шаг 376000: Вероятность выбора лучшего жениха: 0.26
# Шаг 377000: Вероятность выбора лучшего жениха: 0.12
# Шаг 378000: Вероятность выбора лучшего жениха: 0.21
# Шаг 379000: Вероятность выбора лучшего жениха: 0.19
# Шаг 380000: Вероятность выбора лучшего жениха: 0.17
# Шаг 381000: Вероятность выбора лучшего жениха: 0.16
# Шаг 382000: Вероятность выбора лучшего жениха: 0.19
# Шаг 383000: Вероятность выбора лучшего жениха: 0.24
# Шаг 384000: Вероятность выбора лучшего жениха: 0.25
# Шаг 385000: Вероятность выбора лучшего жениха: 0.17
# Шаг 386000: Вероятность выбора лучшего жениха: 0.25
# Шаг 387000: Вероятность выбора лучшего жениха: 0.27
# Шаг 388000: Вероятность выбора лучшего жениха: 0.29
# Шаг 389000: Вероятность выбора лучшего жениха: 0.21
# Шаг 390000: Вероятность выбора лучшего жениха: 0.30
# Шаг 391000: Вероятность выбора лучшего жениха: 0.22
# Шаг 392000: Вероятность выбора лучшего жениха: 0.28
# Шаг 393000: Вероятность выбора лучшего жениха: 0.19
# Шаг 394000: Вероятность выбора лучшего жениха: 0.26
# Шаг 395000: Вероятность выбора лучшего жениха: 0.30
# Шаг 396000: Вероятность выбора лучшего жениха: 0.22
# Шаг 397000: Вероятность выбора лучшего жениха: 0.23
# Шаг 398000: Вероятность выбора лучшего жениха: 0.17
# Шаг 399000: Вероятность выбора лучшего жениха: 0.28
# Шаг 400000: Вероятность выбора лучшего жениха: 0.23
# Шаг 401000: Вероятность выбора лучшего жениха: 0.24
# Шаг 402000: Вероятность выбора лучшего жениха: 0.19
# Шаг 403000: Вероятность выбора лучшего жениха: 0.19
# Шаг 404000: Вероятность выбора лучшего жениха: 0.34
# Шаг 405000: Вероятность выбора лучшего жениха: 0.31
# Шаг 406000: Вероятность выбора лучшего жениха: 0.22
# Шаг 407000: Вероятность выбора лучшего жениха: 0.24
# Шаг 408000: Вероятность выбора лучшего жениха: 0.24
# Шаг 409000: Вероятность выбора лучшего жениха: 0.19
# Шаг 410000: Вероятность выбора лучшего жениха: 0.23
# Шаг 411000: Вероятность выбора лучшего жениха: 0.26
# Шаг 412000: Вероятность выбора лучшего жениха: 0.28
# Шаг 413000: Вероятность выбора лучшего жениха: 0.23
# Шаг 414000: Вероятность выбора лучшего жениха: 0.19
# Шаг 415000: Вероятность выбора лучшего жениха: 0.25
# Шаг 416000: Вероятность выбора лучшего жениха: 0.19
# Шаг 417000: Вероятность выбора лучшего жениха: 0.29
# Шаг 418000: Вероятность выбора лучшего жениха: 0.35
# Шаг 419000: Вероятность выбора лучшего жениха: 0.31
# Шаг 420000: Вероятность выбора лучшего жениха: 0.25
# Шаг 421000: Вероятность выбора лучшего жениха: 0.30
# Шаг 422000: Вероятность выбора лучшего жениха: 0.32
# Шаг 423000: Вероятность выбора лучшего жениха: 0.30
# Шаг 424000: Вероятность выбора лучшего жениха: 0.28
# Шаг 425000: Вероятность выбора лучшего жениха: 0.22
# Шаг 426000: Вероятность выбора лучшего жениха: 0.30
# Шаг 427000: Вероятность выбора лучшего жениха: 0.20
# Шаг 428000: Вероятность выбора лучшего жениха: 0.34
# Шаг 429000: Вероятность выбора лучшего жениха: 0.25
# Шаг 430000: Вероятность выбора лучшего жениха: 0.23
# Шаг 431000: Вероятность выбора лучшего жениха: 0.16
# Шаг 432000: Вероятность выбора лучшего жениха: 0.29
# Шаг 433000: Вероятность выбора лучшего жениха: 0.29
# Шаг 434000: Вероятность выбора лучшего жениха: 0.24
# Шаг 435000: Вероятность выбора лучшего жениха: 0.24
# Шаг 436000: Вероятность выбора лучшего жениха: 0.25
# Шаг 437000: Вероятность выбора лучшего жениха: 0.28
# Шаг 438000: Вероятность выбора лучшего жениха: 0.28
# Шаг 439000: Вероятность выбора лучшего жениха: 0.29
# Шаг 440000: Вероятность выбора лучшего жениха: 0.30
# Шаг 441000: Вероятность выбора лучшего жениха: 0.24
# Шаг 442000: Вероятность выбора лучшего жениха: 0.18
# Шаг 443000: Вероятность выбора лучшего жениха: 0.29
# Шаг 444000: Вероятность выбора лучшего жениха: 0.23
# Шаг 445000: Вероятность выбора лучшего жениха: 0.28
# Шаг 446000: Вероятность выбора лучшего жениха: 0.28
# Шаг 447000: Вероятность выбора лучшего жениха: 0.29
# Шаг 448000: Вероятность выбора лучшего жениха: 0.31
# Шаг 449000: Вероятность выбора лучшего жениха: 0.30
# Шаг 450000: Вероятность выбора лучшего жениха: 0.23
# Шаг 451000: Вероятность выбора лучшего жениха: 0.24
# Шаг 452000: Вероятность выбора лучшего жениха: 0.24
# Шаг 453000: Вероятность выбора лучшего жениха: 0.19
# Шаг 454000: Вероятность выбора лучшего жениха: 0.23
# Шаг 455000: Вероятность выбора лучшего жениха: 0.24
# Шаг 456000: Вероятность выбора лучшего жениха: 0.19
# Шаг 457000: Вероятность выбора лучшего жениха: 0.15
# Шаг 458000: Вероятность выбора лучшего жениха: 0.13
# Шаг 459000: Вероятность выбора лучшего жениха: 0.23
# Шаг 460000: Вероятность выбора лучшего жениха: 0.13
# Шаг 461000: Вероятность выбора лучшего жениха: 0.27
# Шаг 462000: Вероятность выбора лучшего жениха: 0.21
# Шаг 463000: Вероятность выбора лучшего жениха: 0.28
# Шаг 464000: Вероятность выбора лучшего жениха: 0.22
# Шаг 465000: Вероятность выбора лучшего жениха: 0.27
# Шаг 466000: Вероятность выбора лучшего жениха: 0.29
# Шаг 467000: Вероятность выбора лучшего жениха: 0.30
# Шаг 468000: Вероятность выбора лучшего жениха: 0.28
# Шаг 469000: Вероятность выбора лучшего жениха: 0.26
# Шаг 470000: Вероятность выбора лучшего жениха: 0.25
# Шаг 471000: Вероятность выбора лучшего жениха: 0.24
# Шаг 472000: Вероятность выбора лучшего жениха: 0.33
# Шаг 473000: Вероятность выбора лучшего жениха: 0.26
# Шаг 474000: Вероятность выбора лучшего жениха: 0.23
# Шаг 475000: Вероятность выбора лучшего жениха: 0.27
# Шаг 476000: Вероятность выбора лучшего жениха: 0.23
# Шаг 477000: Вероятность выбора лучшего жениха: 0.23
# Шаг 478000: Вероятность выбора лучшего жениха: 0.23
# Шаг 479000: Вероятность выбора лучшего жениха: 0.23
# Шаг 480000: Вероятность выбора лучшего жениха: 0.17
# Шаг 481000: Вероятность выбора лучшего жениха: 0.19
# Шаг 482000: Вероятность выбора лучшего жениха: 0.22
# Шаг 483000: Вероятность выбора лучшего жениха: 0.22
# Шаг 484000: Вероятность выбора лучшего жениха: 0.17
# Шаг 485000: Вероятность выбора лучшего жениха: 0.25
# Шаг 486000: Вероятность выбора лучшего жениха: 0.26
# Шаг 487000: Вероятность выбора лучшего жениха: 0.21
# Шаг 488000: Вероятность выбора лучшего жениха: 0.28
# Шаг 489000: Вероятность выбора лучшего жениха: 0.28
# Шаг 490000: Вероятность выбора лучшего жениха: 0.21
# Шаг 491000: Вероятность выбора лучшего жениха: 0.14
# Шаг 492000: Вероятность выбора лучшего жениха: 0.18
# Шаг 493000: Вероятность выбора лучшего жениха: 0.19
# Шаг 494000: Вероятность выбора лучшего жениха: 0.14
# Шаг 495000: Вероятность выбора лучшего жениха: 0.28
# Шаг 496000: Вероятность выбора лучшего жениха: 0.26
# Шаг 497000: Вероятность выбора лучшего жениха: 0.28
# Шаг 498000: Вероятность выбора лучшего жениха: 0.31
# Шаг 499000: Вероятность выбора лучшего жениха: 0.21

# %% [markdown]
# # Построение графика изменения вероятности выбора лучшего жениха

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x=range(0, len(probabilities) * 1000, 1000), y=probabilities, marker='o', color='b')
plt.title('Вероятность выбора лучшего жениха за время обучения', fontsize=14)
plt.xlabel('Шаги обучения', fontsize=12)
plt.ylabel('Вероятность', fontsize=12)
plt.grid(True)
plt.show()

# %% [markdown]
# # Финальная оценка вероятности

# %%
final_probability = evaluate_best_groom_probability(env, model, n_episodes=100, log=True)
print(f"\nФинальная вероятность выбора лучшего жениха: {final_probability:.2f}, т.е. {final_probability * 100}%")
# Out:
# Лог сохранен в файл: groom_selection_log.json
#
# Финальная вероятность выбора лучшего жениха: 0.29, т.е. 28.999999999999996%

# %% [markdown]
# # Создание новой среды для тестирования модели с другим распределением рейтинга кандидатов

# %%
import random  # Импортируем модуль random для генерации случайных значений

class GroomSelectionEnv(gym.Env):  # Определяем класс среды наследуя от gym.Env
    def __init__(self, n_candidates=50):  # Инициализация среды
        super().__init__()  # Вызываем конструктор базового класса
        self.n_candidates = n_candidates  # Количество кандидатов
        self.min_rating = random.randint(10, 500)  # Случайный минимальный рейтинг от 10 до 500
        self.max_rating = random.randint(501, 1000)  # Случайный максимальный рейтинг от 501 до 1000
        self.candidates = []  # Список кандидатов
        self.current_step = 0  # Текущий шаг
        self.best_candidate_index = -1  # Индекс лучшего кандидата
        self.improvement_reward = 0  # Награда за улучшение
        self.skipped_grooms_count = 0  # Количество пропущенных кандидатов
        self.viewed_candidates = []  # Список просмотренных кандидатов

        self.action_space = spaces.Discrete(2)  # Дискретное пространство действий: 2 действия (пропуск или выбор)
        self.observation_space = spaces.Box(
            low=0, high=1, shape=(3,), dtype=np.float32  # Наблюдения: рейтинг текущего кандидата, прогресс, количество кандидатов
        )

    def step(self, action):  # Метод выполнения шага
        if self.current_step >= self.n_candidates - 1:  # Проверяем, достигнут ли конец списка кандидатов
            terminated = True  # Флаг завершения
            chosen_groom = True  # Флаг выбора кандидата

            if self.current_step - 1 == self.best_candidate_index:  # Проверяем, выбран ли лучший кандидат
                reward = 1.0  # Награда за выбор лучшего кандидата
            else:
                reward = 0.0  # Минимальная награда при отсутствии выбора лучшего кандидата
            reward += self.improvement_reward  # Добавляем награду за улучшение
            return self._get_obs(), reward, terminated, False, {"chosen_groom": chosen_groom}  # Возвращаем наблюдения, награду и флаги

        reward = 0  # Начальная награда
        terminated = False  # Флаг завершения
        chosen_groom = False  # Флаг выбора кандидата

        if action == 1:  # Если действие - выбор кандидата
            chosen_groom = True  # Кандидат выбран
            if self.current_step == self.best_candidate_index:  # Проверяем, выбран ли лучший кандидат
                reward = 1.0  # Награда за выбор лучшего кандидата
            else:
                if self.viewed_candidates and self.candidates[self.current_step] > max(self.viewed_candidates):
                    reward = 0.1  # Награда за выбор кандидата выше самого высокого из просмотренных
            reward += self.improvement_reward  # Добавляем награду за улучшение
            terminated = True  # Завершаем эпизод
        else:  # Если действие - пропуск кандидата
            self.viewed_candidates.append(self.candidates[self.current_step])  # Запоминаем текущего кандидата
            self.skipped_grooms_count += 1  # Увеличиваем счетчик пропусков
            self.current_step += 1  # Переходим к следующему кандидату

        return self._get_obs(), reward, terminated, False, {"chosen_groom": chosen_groom}  # Возвращаем наблюдения, награду и флаги

    def reset(self, seed=None, options=None):  # Метод сброса среды
        super().reset(seed=seed)  # Сбрасываем базовый класс
        self.min_rating = random.randint(10, 500)  # Перегенерируем случайный минимальный рейтинг от 10 до 500
        self.max_rating = random.randint(501, 1000)  # Перегенерируем случайный максимальный рейтинг от 501 до 1000
        self.candidates = np.random.uniform(self.min_rating, self.max_rating, self.n_candidates)  # Генерируем случайные рейтинги кандидатов
        np.random.shuffle(self.candidates)  # Перемешиваем кандидатов случайным образом
        self.best_candidate_index = np.argmax(self.candidates)  # Определяем индекс лучшего кандидата
        self.current_step = 0  # Сбрасываем текущий шаг
        self.skipped_grooms_count = 0  # Сбрасываем счетчик пропусков
        self.viewed_candidates = []  # Сбрасываем список просмотренных кандидатов
        return self._get_obs(), {}  # Возвращаем начальные наблюдения

    def _get_obs(self):  # Метод получения наблюдений
        if self.current_step >= self.n_candidates:  # Проверяем, достигнут ли конец списка кандидатов
            candidate_value = self.candidates[-1]  # Рейтинг последнего кандидата
        else:
            candidate_value = self.candidates[self.current_step]  # Рейтинг текущего кандидата

        progress = min(1.0, self.current_step / self.n_candidates)  # Расчет прогресса
        return np.array([candidate_value, progress, self.n_candidates], dtype=np.float32)  # Возвращаем наблюдения

    def set_improvement_reward(self, reward):  # Метод установки награды за улучшение
        self.improvement_reward = reward  # Устанавливаем награду за улучшение

# %% [markdown]
# # Тест

# %%
final_probability = evaluate_best_groom_probability(env, model, n_episodes=100, log=True)
print(f"\nФинальная вероятность выбора лучшего жениха: {final_probability:.2f}, т.е. {final_probability * 100}%")
# Out:
# Лог сохранен в файл: groom_selection_log.json
#
# Финальная вероятность выбора лучшего жениха: 0.34, т.е. 34.0%

# %% [markdown]
# Анимация

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np

def create_animation(env, model, filename='groom_selection_animation.gif'):
    fig, ax = plt.subplots()
    ax.set_xlim(0, env.n_candidates)
    ax.set_ylim(0, 1)
    ax.set_xlabel('Шаги')
    ax.set_ylabel('Рейтинг женихов')
    bride, = ax.plot([], [], 'mo', label='Невеста')  # Фиолетовая невеста
    grooms = ax.scatter([], [], c='blue', label='Женихи')  # Женихи
    result_text = ax.text(0.5, 0.9, '', transform=ax.transAxes, ha='center', va='center', fontsize=14, color='black')
    ax.legend()

    def init():
        bride.set_data([], [])
        grooms.set_offsets(np.array([]).reshape(0, 2))
        result_text.set_text('')
        return bride, grooms, result_text

    def animate(i):
        obs, _ = env.reset()
        done = False
        steps = []
        values = []
        colors = ['blue'] * env.n_candidates  # Изначально все женихи синие

        while not done:
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, done, truncated, info = env.step(action)
            done = done or truncated
            steps.append(env.current_step)
            values.append(obs[0])

            if action == 1:
                if env.current_step == env.best_candidate_index:
                    colors[env.current_step] = 'green'  # Невеста выбрала лучшего жениха
                    result_text.set_text('ПОБЕДА')
                else:
                    colors[env.current_step] = 'red'  # Невеста выбрала не лучшего жениха
                    result_text.set_text('ПОРАЖЕНИЕ')
                break
            else:
                colors[env.current_step] = 'red'  # Невеста отказала жениху

        bride.set_data([env.current_step], [obs[0]])
        grooms.set_offsets(np.c_[steps, values])
        grooms.set_color(colors[:len(steps)])
        return bride, grooms, result_text

    ani = animation.FuncAnimation(fig, animate, init_func=init, frames=env.n_candidates, interval=500, blit=True)
    ani.save(filename, writer='pillow')

# Пример использования
create_animation(env, model)

# %% [markdown]
# Метрики

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score

def evaluate_metrics(env, model, n_episodes=100):
    y_true = []  # Истинные значения
    y_pred = []  # Предсказанные значения

    for episode in range(n_episodes):
        obs, _ = env.reset()
        done = False

        while not done:
            action, _ = model.predict(obs, deterministic=True)
            obs, reward, done, truncated, info = env.step(action)
            done = done or truncated

            if action == 1:
                y_true.append(int(env.current_step == env.best_candidate_index))  # 1 если лучший жених, 0 иначе
                y_pred.append(int(action == 1))  # 1 если выбран, 0 иначе

    accuracy = accuracy_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)

    print(f"Точность (Accuracy): {accuracy:.2f}")
    print(f"Полнота (Recall): {recall:.2f}")
    print(f"Точность (Precision): {precision:.2f}")
    print(f"F1-Score: {f1:.2f}")

# Пример использования
evaluate_metrics(env, model)
# Out:
# Точность (Accuracy): 0.25
# Полнота (Recall): 1.00
# Точность (Precision): 0.25
# F1-Score: 0.40
